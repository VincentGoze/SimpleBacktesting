# %% [markdown]
# # Backtest of simple strategies

# %% [markdown]
# ## Description of the notebook

# %% [markdown]
# This notebook is in continuous development. This notebook implements multiple trading signals and backtests them on major US stocks. We begin by testing them individually, trying to optimize the parameters involved in the signal, and visualize the results. After that, we aggregate those signals to develop a strategy acting like a voting classifier.
#
# To do:
# - Add transaction fees and spreads
# - Improve modularity to allow easy integration of new signals, backtest methods and evaluation metrics
# - Extend strategies to multiple stocks and asset classes
# - Implement new performance metrics
# - Implement Machine learning to optimize the parameters and separate data in training and validation set
# - ...

# %% [markdown]
# ## Imports and data retrieval

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import itertools

# %%
#stock_names=["NVDA","MSFT","AAPL","GOOG","AMZN","META"]

dat = yf.Ticker("AAPL") #Testing with one stock to start

# %%
df=dat.history(start="2019-11-30")

# %%
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2019-12-02 00:00:00-05:00  64.549256  64.785941  63.626681  63.798153
# 2019-12-03 00:00:00-05:00  62.385289  62.679936  61.897435  62.660618
# 2019-12-04 00:00:00-05:00  63.051871  63.592858  62.957677  63.213680
# 2019-12-05 00:00:00-05:00  63.708795  64.215974  63.452791  64.141098
# 2019-12-06 00:00:00-05:00  64.599990  65.450114  64.556512  65.380074
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-12-02 00:00:00-05:00   94487200        0.0           0.0
# 2019-12-03 00:00:00-05:00  114430400        0.0           0.0
# 2019-12-04 00:00:00-05:00   67181600        0.0           0.0
# 2019-12-05 00:00:00-05:00   74424400        0.0           0.0
# 2019-12-06 00:00:00-05:00  106075600        0.0           0.0

# %% [markdown]
# ## Implementation of some signals

# %% [markdown]
# Return best parameters, and then do the sum of signals to try new method</span>.

# %%
def mean_reversion_signal(df,prices_column,window,threshold):
    """
    buy if price is lower than the mean of previous days (adjustable threshold)
    sell if price is higher 
    """
    means=df[prices_column].rolling(window).mean().shift(1)
    signal_column=[]
    for p,m in zip(df[prices_column], means):
        if p < (1-threshold)*m:
            signal_column.append(1)
        elif p > (1+threshold)*m:
            signal_column.append(-1)
        else:
            signal_column.append(0)
    return signal_column


def alligator_signal(df,prices_column,jaw_window=13,teeth_window=8,lips_window=5,jaw_shift=8,teeth_shift=5,lips_shift=3):
    """
    https://chartschool.stockcharts.com/table-of-contents/technical-indicators-and-overlays/technical-indicators/alligator-indicator
    For now, we keep the default parameters. We will maybe optimize later
    """
    
    # average of the high and low prices are typically used but we'll use Close for simplicity here
    jaws = df[prices_column].rolling(window=jaw_window).mean().shift(1+jaw_shift)          #in this setting, we take decisions on the day after, which explains the "1+"
    teeth = df[prices_column].rolling(window=teeth_window).mean().shift(1+teeth_shift)
    lips = df[prices_column].rolling(window=lips_window).mean().shift(1+lips_shift)

    signal_column = []
    for l, t, j in zip(lips, teeth, jaws):
        if l > t > j:
            signal_column.append(1)   
        elif l < t < j:
            signal_column.append(-1)  
        else:
            signal_column.append(0)   
    return signal_column

    
def rsi_signal(df,prices_column,window,lower_threshold,upper_threshold):
    """
    RSI(Relative Strength Index)
    high value=too many buyers --> sell
    low value=too many sellers --> buy
    implemented with a simple moving average (not exponential)
    """

    #Average gains and losses
    delta = df[prices_column].diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(window=window, min_periods=window).mean()
    avg_loss = loss.rolling(window=window, min_periods=window).mean()
    

    rsi = 100 - (100 / (1 + avg_gain / avg_loss))
    
    
    signal_column = []
    for val in rsi:
        if val < lower_threshold:
            signal_column.append(1)
        elif val > upper_threshold:
            signal_column.append(-1)
        else:
            signal_column.append(0)
    
    return signal_column

def moving_average_crossover_signal(df, prices_column, short_window, long_window, threshold):
    """
    Buy when the short average crosses above the long average.
    Sell when short avg. crosses below short avg.
    Use a threshold to avoid "noise"
    """
    short_avg = df[prices_column].rolling(short_window).mean().shift(1)
    long_avg = df[prices_column].rolling(long_window).mean().shift(1)
    
    signal_column = []
    
    for s,l in zip(short_avg,long_avg):
        if s > (1+threshold)*l:   
            signal_column.append(1)
        elif s < (1-threshold)*l: 
            signal_column.append(-1)
        else:
            signal_column.append(0)
    
    return signal_column

# %% [markdown]
# # Grid-Search type optimization

# %%
def optimize_signal_parameters(signal_name,df,prices_column,parameters,pourcentages_buy,start_date="2020-01-01",initial_amount=100000,cutoff_threshold=2):
    """
    Given a signal_name function, test different parameters as well as different pourcentages allocation of portfolio when buying stocks on a dataframe df.
    The best results are plotted and compared to a Buy & Hold benchmark
    """

    # Buy & Hold benchmark
    plt.figure(figsize=(12, 6))
    df=df[df.index>=start_date]
    to_buy=math.floor(initial_amount/df.iloc[0]["Open"])
    cash_residual=initial_amount-to_buy*df.iloc[0]["Open"]
    buy_hold_value= cash_residual+to_buy*df["Open"]
    plt.plot(df.index, buy_hold_value, label='Buy & Hold', linestyle='--', color='black')


    best_parameters=0
    best_value=0
    
    
    #Parsing parameters and iterating over them
    parameters_keys = list(parameters.keys())
    for values in itertools.product(*parameters.values()):  
        for pourcentage in pourcentages_buy:
            
            cash=initial_amount
            n_shares=0
            
            signal=signal_name(df,prices_column,*values)
            nr_shares=[]
            total_value=[]
            for a in range(len(df)):
                row=df.iloc[a]
                sig=signal[a]
                if sig==1: #allocate pourcentage% of remaining cash to buy stocks
                    to_buy=math.floor(pourcentage*cash/row["Open"])
                    n_shares+=to_buy
                    cash-=(to_buy*row["Open"])
                elif sig==-1: #sell all acquired stocks
                    cash+=(n_shares*row["Open"])
                    n_shares=0
                nr_shares.append(n_shares)
                total_value.append(cash+n_shares*row["Open"])


            #Visualize only "good" results, those who multiply the initial_amount by at least cutoff_threshold
            if total_value[-1]>cutoff_threshold*initial_amount:
                print(f"{parameters_keys}={values}, Pourcentage={pourcentage}, Total Value={total_value[-1]:.2f}$")
                plt.plot(df.index, total_value, label=f'Parameters={values}')

            #Keeping track if best value
            if total_value[-1]>best_value:
                best_value=total_value[-1]
                best_parameters=dict(zip(parameters_keys,values))
                #we can return the pourcentage if we want
                #   best_parameters["pourcentages_buy"]=pourcentage  
                #After some experiments, we are going to keep pourcentage=1, which seems to work best
                
            
    plt.show()

    #Return tracked best value
    return best_value, best_parameters

# %%
#Keeping track of the "optimized" parameters (those parameters are optimized only on one stock and one a specific start date)
#They are not the optimal solution for all stocks but gives us a starting point
best_parameters={}

# %%
best_value_mean_reversion, best_parameters["mean_reversion"]=optimize_signal_parameters(mean_reversion_signal,df,"Close",{"window":[4,10,15,20],"threshold":[0,0.02,0.05,0.08]},pourcentages_buy=[0.2,0.5,0.65,0.8],cutoff_threshold=1.3)

#The result with this signal is not very good
# Out:
# ['window', 'threshold']=(4, 0.08), Pourcentage=0.5, Total Value=135302.01$
# ['window', 'threshold']=(4, 0.08), Pourcentage=0.65, Total Value=139697.55$
# ['window', 'threshold']=(4, 0.08), Pourcentage=0.8, Total Value=143083.35$
# ['window', 'threshold']=(10, 0.08), Pourcentage=0.2, Total Value=143602.85$
# ['window', 'threshold']=(10, 0.08), Pourcentage=0.5, Total Value=147458.56$
# ['window', 'threshold']=(10, 0.08), Pourcentage=0.65, Total Value=142439.80$
# ['window', 'threshold']=(10, 0.08), Pourcentage=0.8, Total Value=137398.71$

# %%
best_value_rsi, best_parameters["rsi"]=optimize_signal_parameters(rsi_signal,df,"Close",{"window":[10,15,20],"lower_threshold":[20,30],"upper_threshold":[70,80]},[0.2,0.5,0.65,0.8,0.9,1],)
# Out:
# ['window', 'lower_threshold', 'upper_threshold']=(15, 30, 80), Pourcentage=0.5, Total Value=202031.68$
# ['window', 'lower_threshold', 'upper_threshold']=(15, 30, 80), Pourcentage=0.65, Total Value=206257.99$
# ['window', 'lower_threshold', 'upper_threshold']=(15, 30, 80), Pourcentage=0.8, Total Value=205380.02$
# ['window', 'lower_threshold', 'upper_threshold']=(15, 30, 80), Pourcentage=0.9, Total Value=202789.97$
# ['window', 'lower_threshold', 'upper_threshold']=(20, 30, 80), Pourcentage=0.5, Total Value=264372.33$
# ['window', 'lower_threshold', 'upper_threshold']=(20, 30, 80), Pourcentage=0.65, Total Value=285320.51$
# ['window', 'lower_threshold', 'upper_threshold']=(20, 30, 80), Pourcentage=0.8, Total Value=300187.41$
# ['window', 'lower_threshold', 'upper_threshold']=(20, 30, 80), Pourcentage=0.9, Total Value=306770.11$
# ['window', 'lower_threshold', 'upper_threshold']=(20, 30, 80), Pourcentage=1, Total Value=310254.49$

# %%
best_value_crossover, best_parameters["crossover"]=optimize_signal_parameters(moving_average_crossover_signal,df,"Close",{"short_window":[10,15,20],"long_window":[30,40,50],"threshold":[0,0.02,0.05,0.08]},[0.2,0.5,0.65,0.8,0.9,1],cutoff_threshold=2.5)
# Out:
# ['short_window', 'long_window', 'threshold']=(15, 50, 0.02), Pourcentage=0.65, Total Value=254577.67$
# ['short_window', 'long_window', 'threshold']=(15, 50, 0.02), Pourcentage=0.8, Total Value=258445.33$
# ['short_window', 'long_window', 'threshold']=(15, 50, 0.02), Pourcentage=0.9, Total Value=259909.10$
# ['short_window', 'long_window', 'threshold']=(15, 50, 0.02), Pourcentage=1, Total Value=260527.61$
# ['short_window', 'long_window', 'threshold']=(20, 30, 0.02), Pourcentage=0.5, Total Value=256260.74$
# ['short_window', 'long_window', 'threshold']=(20, 30, 0.02), Pourcentage=0.65, Total Value=259297.09$
# ['short_window', 'long_window', 'threshold']=(20, 30, 0.02), Pourcentage=0.8, Total Value=261369.03$
# ['short_window', 'long_window', 'threshold']=(20, 30, 0.02), Pourcentage=0.9, Total Value=262229.55$
# ['short_window', 'long_window', 'threshold']=(20, 30, 0.02), Pourcentage=1, Total Value=262662.23$
# ['short_window', 'long_window', 'threshold']=(20, 50, 0.08), Pourcentage=0.5, Total Value=252567.33$
# ['short_window', 'long_window', 'threshold']=(20, 50, 0.08), Pourcentage=0.65, Total Value=252600.07$
# ['short_window', 'long_window', 'threshold']=(20, 50, 0.08), Pourcentage=0.8, Total Value=252799.37$
# ['short_window', 'long_window', 'threshold']=(20, 50, 0.08), Pourcentage=0.9, Total Value=252992.44$
# ['short_window', 'long_window', 'threshold']=(20, 50, 0.08), Pourcentage=1, Total Value=253115.75$

# %%
best_value_alligator, best_parameters["alligator"]=optimize_signal_parameters(alligator_signal,df,"Close",{},[0.2,0.5,0.65,0.8,0.9,1],cutoff_threshold=2.5)
# Out:
# []=(), Pourcentage=0.5, Total Value=255242.51$
# []=(), Pourcentage=0.65, Total Value=263552.68$
# []=(), Pourcentage=0.8, Total Value=269172.26$
# []=(), Pourcentage=0.9, Total Value=271644.65$
# []=(), Pourcentage=1, Total Value=273038.18$

# %% [markdown]
# ## Combining the signals

# %% [markdown]
# This section needs to be cleaned: add modularity to allow for different combinations of signals

# %% [markdown]
# When we combine all three signals, the results is mediocre

# %%
def test_combined_signals(df,prices_column,signals_dictionary,initial_amount=100000,start_date="2020-01-01"):

    # Buy & Hold benchmark
    plt.figure(figsize=(12, 6))
    df=df[df.index>=start_date]
    to_buy=math.floor(initial_amount/df.iloc[0]["Open"])
    cash_residual=initial_amount-to_buy*df.iloc[0]["Open"]
    buy_hold_value= cash_residual+to_buy*df["Open"]
    plt.plot(df.index, buy_hold_value, label='Buy & Hold', linestyle='--', color='black')



    
    signals_columns=[pd.Series(signal(df,prices_column,*signals_dictionary[signal].values())) for signal in signals_dictionary.keys()]
    #signal_1=mean_reversion_signal(df,"Close",*best_parameters_mean_reversion.values())
    #signal_2=rsi_signal(df,"Close",*best_parameters_rsi.values())
    #signal_3=moving_average_crossover_signal(df,"Close",*best_parameters_crossover.values())
    sum_of_signals=sum(signals_columns)
    cash=initial_amount
    n_shares=0
    
    
    nr_shares=[]
    total_value=[]
    
    for a in range(len(df)):
        row=df.iloc[a]
        sig=sum_of_signals[a]
        if sig>0: 
            to_buy=math.floor(1*cash/row["Open"])
            n_shares+=to_buy
            cash-=(to_buy*row["Open"])
        elif sig<0: #sell all acquired stocks
            cash+=(n_shares*row["Open"])
            n_shares=0
        nr_shares.append(n_shares)
        total_value.append(cash+n_shares*row["Open"])
    
    
    
    
    print(f"Total Value={total_value[-1]:.2f}$")
    plt.plot(df.index, total_value)
    
    
            
    plt.show()

signals_dictionary={moving_average_crossover_signal:best_parameters["crossover"],rsi_signal:best_parameters["rsi"],alligator_signal:best_parameters["alligator"]}
signals_dictionary={moving_average_crossover_signal:best_parameters["crossover"],rsi_signal:best_parameters["rsi"]}
print(*signals_dictionary[moving_average_crossover_signal].values())
print([signals_dictionary[a] for a in signals_dictionary.keys()])
test_combined_signals(df,"Close",signals_dictionary)

#[signal(df,"Close",*best_parameters[signals_dictionary[signal]]) for signal in signals_dictionary.keys()]
# Out:
# 20 30 0.02
# [{'short_window': 20, 'long_window': 30, 'threshold': 0.02}, {'window': 20, 'lower_threshold': 30, 'upper_threshold': 80}]
# Total Value=244044.57$

# %% [markdown]
# Howeer, whan we only keep the two best signals, we outperform the Buy&Hold benchmark

# %%
# Buy & Hold benchmark
start_date="2020-01-01"
initial_amount=100000
plt.figure(figsize=(12, 6))
df=df[df.index>=start_date]
to_buy=math.floor(initial_amount/df.iloc[0]["Open"])
cash_residual=initial_amount-to_buy*df.iloc[0]["Open"]
buy_hold_value= cash_residual+to_buy*df["Open"]
print(f"Buy&Hold value: {buy_hold_value.iloc[-1]}$")
plt.plot(df.index, buy_hold_value, label='Buy & Hold', linestyle='--', color='black')





signal_1=mean_reversion_signal(df,"Close",*best_parameters_mean_reversion.values())
signal_1=[0]*len(signal_1)
signal_2=rsi_signal(df,"Close",*best_parameters_rsi.values())
signal_3=moving_average_crossover_signal(df,"Close",*best_parameters_crossover.values())

cash=initial_amount
n_shares=0


nr_shares=[]
total_value=[]

for a in range(len(df)):
    row=df.iloc[a]
    sig=signal_1[a]+signal_2[a]+signal_3[a]
    if sig>0: 
        to_buy=math.floor(0.8*cash/row["Open"])
        n_shares+=to_buy
        cash-=(to_buy*row["Open"])
    elif sig<0: #sell all acquired stocks
        cash+=(n_shares*row["Open"])
        n_shares=0
    nr_shares.append(n_shares)
    total_value.append(cash+n_shares*row["Open"])




print(f"Total Value={total_value[-1]:.2f}$")
plt.plot(df.index, total_value, label=f'Parameters={values}')


        
plt.show()
# Out:
# Buy&Hold value: 320312.64195399336$
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 16
#       9 print(f"Buy&Hold value: {buy_hold_value.iloc[-1]}$")
#      10 plt.plot(df.index, buy_hold_value, label='Buy & Hold', linestyle='--', color='black')
# ---> 16 signal_1=mean_reversion_signal(df,"Close",*best_parameters_mean_reversion.values())
#      17 signal_1=[0]*len(signal_1)
#      18 signal_2=rsi_signal(df,"Close",*best_parameters_rsi.values())
#
# NameError: name 'best_parameters_mean_reversion' is not defined

# %%
a=pd.Series([1,2])
b=pd.Series([1,2])
c=[a,b]

# %%
sum(c)
# Out:
# 0    2
# 1    4
# dtype: int64
